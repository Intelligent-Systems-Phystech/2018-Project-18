# %%
from scipy.io import loadmat
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = '../../Downloads/BCICIV_4_mat/'
x_1 = os.path.join(dataset, 'sub1_comp.mat')
x_2 = os.path.join(dataset, 'sub1_comp.mat')
x_3 = os.path.join(dataset, 'sub1_comp.mat')

# %%
x = loadmat(x_1)

# %%
print(x.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'train_data', 'test_data', 'train_dg'])

# %%
print(np.array(x["train_data"]).shape)
print(x.shape)
# Out:
# (400000, 62)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-aeb43f0371b1> in <module>
#       1 print(np.array(x["train_data"]).shape)
# ----> 2 print(x.shape)
#
# AttributeError: 'dict' object has no attribute 'shape'

# %%
np.array()

# %%
for ch in np.array(x['train_data']).
# Out:
#   File "<ipython-input-66-32285394e7f2>", line 1
#     for ch in np.array(x['train_data']).
#                                         ^
# SyntaxError: invalid syntax

# %%
for fing in fingers:
    plt.figure(figsize=(16,6))
    plt.title(str(fing+1))
    plt.plot(np.array(x['train_dg'])[:40000,fing])
